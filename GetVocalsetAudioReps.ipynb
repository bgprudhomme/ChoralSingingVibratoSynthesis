# %%
import os
# !pip install pyworld
import pyworld as pw
import numpy as np
import soundfile as sf
import librosa
# Out:
# Requirement already satisfied: pyworld in /usr/local/lib/python3.11/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyworld) (2.0.2)

# %%
def extract_features(y, sr):
    y = y.astype(np.float64)

    # === Use librosa.pyin's default frame_length and hop_length ===
    # Default frame_length = 2048, default hop_length = frame_length // 4 = 512
    pyin_hop_length = 2048 // 4 # Explicitly define for clarity
    pyin_frame_length = 2048

    # === Extract F0 using librosa.pyin ===
    f0, voiced_flag, _ = librosa.pyin(
        y, sr=sr,
        fmin=librosa.note_to_hz('C2'),
        fmax=librosa.note_to_hz('C7'),
        frame_length=pyin_frame_length, # Using default
        hop_length=pyin_hop_length    # Using default
    )

    # === Create accurate timestamps for F0 ===
    times_f0 = librosa.times_like(f0, sr=sr, hop_length=pyin_hop_length)

    # === Clean F0 ===
    f0_clean = f0.copy()
    mask = np.isnan(f0_clean) | (f0_clean == 0)
    if np.any(mask):
        # Ensure there are valid points to interpolate from
        valid_indices = np.flatnonzero(~mask)
        nan_indices = np.flatnonzero(mask)
        if len(valid_indices) > 0:
            f0_clean[mask] = np.interp(nan_indices, valid_indices, f0_clean[valid_indices])
        else: # All values are NaN or zero, fill with zero
            f0_clean[mask] = 0.0
    f0_clean = np.nan_to_num(f0_clean, nan=0.0) # Final check for any remaining NaNs

    # === RMS energy, aligned to the same hop rate ===
    # Use the same frame_length and hop_length as pyin for consistency
    rms = librosa.feature.rms(y=y, frame_length=pyin_frame_length, hop_length=pyin_hop_length)[0]

    # Align lengths (truncate/pad if librosa.feature.rms produces slightly different num_frames)
    min_len = min(len(f0_clean), len(rms))
    f0_clean = f0_clean[:min_len]
    times_f0 = times_f0[:min_len]
    rms = rms[:min_len]

    # === Spectral envelope ===
    # Ensure f0_clean has 0 for unvoiced for cheaptrick (pyin's voiced_flag can help here if preferred)
    f0_for_cheaptrick = f0_clean.copy()
    # Example: If you want to be strict based on voiced_flag (after aligning its length too)
    # voiced_flag_aligned = voiced_flag[:min_len]
    # f0_for_cheaptrick[~voiced_flag_aligned] = 0.0

    sp = pw.cheaptrick(y, f0_for_cheaptrick, times_f0, sr)

    return times_f0, f0_clean, rms, sp, (pyin_hop_length / sr)

# %%
root_input = "/content/drive/MyDrive/data/VocalSet Singing Voice Dataset/FULL"
root_output = "/content/drive/MyDrive/data/audio_reps/VocalSet4"

os.makedirs(root_output, exist_ok=True)

include_folders = {
    "arpeggios": ["straight", "vibrato", "fast_forte", "fast_piano", "slow_forte", "slow_piano"],
    "scales":    ["straight", "vibrato", "fast_forte", "fast_piano", "slow_forte", "slow_piano"],
    "long_tones": ["straight", "messa", "forte", "pp"],
}

# %%
# FRAME DATA GENERATION
# 🚀 Traverse each singer
for singer in os.listdir(root_input):
    singer_path = os.path.join(root_input, singer)
    if not os.path.isdir(singer_path):
        continue

    for top_level, allowed_subdirs in include_folders.items():
        top_level_path = os.path.join(singer_path, top_level)
        if not os.path.isdir(top_level_path):
            continue

        for subdir in allowed_subdirs:
            subdir_path = os.path.join(top_level_path, subdir)
            if not os.path.isdir(subdir_path):
                continue

            for filename in os.listdir(subdir_path):
                if not filename.endswith(".wav"):
                    continue

                file_path = os.path.join(subdir_path, filename)

                # 🗂 Construct output path
                rel_path = os.path.relpath(file_path, root_input)
                outname = os.path.splitext(rel_path)[0]
                full_output_path = os.path.join(root_output, outname)
                os.makedirs(os.path.dirname(full_output_path), exist_ok=True)

                if os.path.exists(full_output_path + "_features.npz"):
                  print(f"⏩ Skipping {filename}: features already exist")
                  continue

                # 📥 Load full audio
                y, sr = librosa.load(file_path, sr=None) # sr becomes 44100
                frame_length = 2048
                hop_length = 512
                rms = librosa.feature.rms(y=y, frame_length=frame_length, hop_length=hop_length)[0]
                times = librosa.frames_to_time(np.arange(len(rms)), sr=sr, hop_length=hop_length)

                # ✂️ Trim start/end silence based on threshold
                threshold = 0.005
                active_frames = np.where(rms > threshold)[0]
                if len(active_frames) < 3:
                    print(f"⚠️ Skipping {filename}: not enough active frames")
                    continue

                start_sample = int(times[active_frames[0]] * sr)
                end_sample = int(times[active_frames[-1]] * sr)
                y_trimmed = y[start_sample:end_sample]

                # 🎯 Extract pitch, RMS, spectrogram, and metadata
                time_vals, f0_vals, rms_vals, M, hop = extract_features(y_trimmed, sr=sr)

                print(M.shape)

                # 💾 Save single CSV: time, f0, rms, M0, M1, ...
                csv_data = np.column_stack((time_vals, f0_vals, rms_vals, M))
                np.savez_compressed(full_output_path + "_features.npz",
                    time=time_vals, f0=f0_vals, rms=rms_vals, M=M)

                print(f"✅ Saved trimmed features for {filename}: {csv_data.shape[0]} frames")
# Out:
# (489, 1025)
# ✅ Saved trimmed features for f9_arpeggios_straight_o.wav: 489 frames
# (505, 1025)
# ✅ Saved trimmed features for f9_arpeggios_straight_e.wav: 505 frames
# (500, 1025)
# ✅ Saved trimmed features for f9_arpeggios_straight_i.wav: 500 frames
# (514, 1025)
# ✅ Saved trimmed features for f9_arpeggios_straight_a.wav: 514 frames
# (527, 1025)
# ✅ Saved trimmed features for f9_arpeggios_straight_u.wav: 527 frames
# (574, 1025)
# ✅ Saved trimmed features for f9_arpeggios_vibrato_i.wav: 574 frames
# (553, 1025)
# ✅ Saved trimmed features for f9_arpeggios_vibrato_a.wav: 553 frames
# (556, 1025)
# ✅ Saved trimmed features for f9_arpeggios_vibrato_e.wav: 556 frames
# (550, 1025)
# ✅ Saved trimmed features for f9_arpeggios_vibrato_o.wav: 550 frames
# (561, 1025)
# ✅ Saved trimmed features for f9_arpeggios_vibrato_u.wav: 561 frames
# (155, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_fast_forte_o.wav: 155 frames
# (128, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_forte_a.wav: 128 frames
# (145, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_forte_o.wav: 145 frames
# (172, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_fast_forte_i.wav: 172 frames
# (142, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_fast_forte_a.wav: 142 frames
# (156, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_forte_u.wav: 156 frames
# (151, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_fast_forte_e.wav: 151 frames
# (1566, 1025)
# ✅ Saved trimmed features for arps_fast_piano_c.wav: 1566 frames
# (143, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_forte_e.wav: 143 frames
# (164, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_fast_forte_u.wav: 164 frames
# (142, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_forte_i.wav: 142 frames
# (141, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_piano_i.wav: 141 frames
# (145, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_piano_u.wav: 145 frames
# (121, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_piano_a.wav: 121 frames
# (127, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_piano_e.wav: 127 frames
# (143, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_fast_piano_o.wav: 143 frames
# (593, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_forte_e.wav: 593 frames
# (453, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_forte_a.wav: 453 frames
# (518, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_forte_u.wav: 518 frames
# (480, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_forte_o.wav: 480 frames
# (488, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_forte_i.wav: 488 frames
# (665, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_forte_u.wav: 665 frames
# (598, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_forte_o.wav: 598 frames
# (560, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_forte_a.wav: 560 frames
# (492, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_forte_e.wav: 492 frames
# (666, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_forte_i.wav: 666 frames
# (609, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_piano_e.wav: 609 frames
# (686, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_piano_i.wav: 686 frames
# (504, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_piano_e.wav: 504 frames
# (498, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_piano_a.wav: 498 frames
# (561, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_piano_i.wav: 561 frames
# (542, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_piano_u.wav: 542 frames
# (650, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_piano_u.wav: 650 frames
# (498, 1025)
# ✅ Saved trimmed features for f9_arpeggios_f_slow_piano_o.wav: 498 frames
# (637, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_piano_o.wav: 637 frames
# (617, 1025)
# ✅ Saved trimmed features for f9_arpeggios_c_slow_piano_a.wav: 617 frames
# (613, 1025)
# ✅ Saved trimmed features for f9_scales_straight_u.wav: 613 frames
# (584, 1025)
# ✅ Saved trimmed features for f9_scales_straight_o.wav: 584 frames
# (560, 1025)
# ✅ Saved trimmed features for f9_scales_straight_e.wav: 560 frames
# (569, 1025)
# ✅ Saved trimmed features for f9_scales_straight_a.wav: 569 frames
# (615, 1025)
# ✅ Saved trimmed features for f9_scales_straight_i.wav: 615 frames
# (783, 1025)
# ✅ Saved trimmed features for f9_scales_vibrato_e.wav: 783 frames
# (799, 1025)
# ✅ Saved trimmed features for f9_scales_vibrato_a.wav: 799 frames
# (744, 1025)
# ✅ Saved trimmed features for f9_scales_vibrato_o.wav: 744 frames
# (808, 1025)
# ✅ Saved trimmed features for f9_scales_vibrato_i.wav: 808 frames
# (825, 1025)
# ✅ Saved trimmed features for f9_scales_vibrato_u.wav: 825 frames
# (314, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_forte_e.wav: 314 frames
# (301, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_forte_i.wav: 301 frames
# (309, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_forte_u.wav: 309 frames
# (274, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_forte_a.wav: 274 frames
# (328, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_forte_i.wav: 328 frames
# (310, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_forte_u.wav: 310 frames
# (313, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_forte_o.wav: 313 frames
# (317, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_forte_a.wav: 317 frames
# (297, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_forte_e.wav: 297 frames
# (302, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_forte_o.wav: 302 frames
# (272, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_piano_a.wav: 272 frames
# (275, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_piano_e.wav: 275 frames
# (267, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_piano_a.wav: 267 frames
# (281, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_piano_i.wav: 281 frames
# (269, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_piano_o.wav: 269 frames
# (288, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_piano_u.wav: 288 frames
# (279, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_piano_o.wav: 279 frames
# (290, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_piano_i.wav: 290 frames
# (273, 1025)
# ✅ Saved trimmed features for f9_scales_f_fast_piano_e.wav: 273 frames
# (275, 1025)
# ✅ Saved trimmed features for f9_scales_c_fast_piano_u.wav: 275 frames
# (845, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_forte_e.wav: 845 frames
# (801, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_forte_a.wav: 801 frames
# (788, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_forte_e.wav: 788 frames
# (863, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_forte_a.wav: 863 frames
# (847, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_forte_i.wav: 847 frames
# (869, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_forte_o.wav: 869 frames
# (907, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_forte_u.wav: 907 frames
# (826, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_forte_o.wav: 826 frames
# (852, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_forte_u.wav: 852 frames
# (877, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_forte_i.wav: 877 frames
# (833, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_piano_e.wav: 833 frames
# (826, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_piano_u.wav: 826 frames
# (831, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_piano_i.wav: 831 frames
# (826, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_piano_e.wav: 826 frames
# (816, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_piano_a.wav: 816 frames
# (806, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_piano_a.wav: 806 frames
# (799, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_piano_u.wav: 799 frames
# (827, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_piano_o.wav: 827 frames
# (859, 1025)
# ✅ Saved trimmed features for f9_scales_c_slow_piano_i.wav: 859 frames
# (813, 1025)
# ✅ Saved trimmed features for f9_scales_f_slow_piano_o.wav: 813 frames
# (629, 1025)
# ✅ Saved trimmed features for f9_long_straight_e.wav: 629 frames
# (566, 1025)
# ✅ Saved trimmed features for f9_long_straight_a.wav: 566 frames
# (593, 1025)
# ✅ Saved trimmed features for f9_long_straight_i.wav: 593 frames
# (587, 1025)
# ✅ Saved trimmed features for f9_long_straight_o.wav: 587 frames
# (572, 1025)
# ✅ Saved trimmed features for f9_long_straight_u.wav: 572 frames
# (726, 1025)
# ✅ Saved trimmed features for f9_long_messa_e.wav: 726 frames
# (709, 1025)
# ✅ Saved trimmed features for f9_long_messa_a.wav: 709 frames
# (683, 1025)
# ✅ Saved trimmed features for f9_long_messa_i.wav: 683 frames
# (766, 1025)
# ✅ Saved trimmed features for f9_long_messa_u.wav: 766 frames
# (746, 1025)
# ✅ Saved trimmed features for f9_long_messa_o.wav: 746 frames
# (591, 1025)
# ✅ Saved trimmed features for f9_long_forte_i.wav: 591 frames
# (633, 1025)
# ✅ Saved trimmed features for f9_long_forte_o.wav: 633 frames
# (640, 1025)
# ✅ Saved trimmed features for f9_long_forte_u.wav: 640 frames
# (635, 1025)
# ✅ Saved trimmed features for f9_long_forte_e.wav: 635 frames
# (626, 1025)
# ✅ Saved trimmed features for f9_long_forte_a.wav: 626 frames
# (650, 1025)
# ✅ Saved trimmed features for f9_long_pp_o.wav: 650 frames
# (631, 1025)
# ✅ Saved trimmed features for f9_long_pp_i.wav: 631 frames
# (604, 1025)
# ✅ Saved trimmed features for f9_long_pp_a.wav: 604 frames
# (643, 1025)
# ✅ Saved trimmed features for f9_long_pp_u.wav: 643 frames
# (574, 1025)
# ✅ Saved trimmed features for f9_long_pp_e.wav: 574 frames
# (648, 1025)
# ✅ Saved trimmed features for f7_arpeggios_straight_i.wav: 648 frames
# (630, 1025)
# ✅ Saved trimmed features for f7_arpeggios_straight_a.wav: 630 frames
# (632, 1025)
# ✅ Saved trimmed features for f7_arpeggios_straight_u.wav: 632 frames
# (632, 1025)
# ✅ Saved trimmed features for f7_arpeggios_straight_e.wav: 632 frames
# (641, 1025)
# ✅ Saved trimmed features for f7_arpeggios_straight_o.wav: 641 frames
# (539, 1025)
# ✅ Saved trimmed features for f7_arpeggios_vibrato_a.wav: 539 frames
# (581, 1025)
# ✅ Saved trimmed features for f7_arpeggios_vibrato_o.wav: 581 frames
# (560, 1025)
# ✅ Saved trimmed features for f7_arpeggios_vibrato_u.wav: 560 frames
# (532, 1025)
# ✅ Saved trimmed features for f7_arpeggios_vibrato_e.wav: 532 frames
# (570, 1025)
# ✅ Saved trimmed features for f7_arpeggios_vibrato_i.wav: 570 frames
# (183, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_forte_u.wav: 183 frames
# (164, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_forte_o.wav: 164 frames
# (183, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_forte_u.wav: 183 frames
# (173, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_forte_i.wav: 173 frames
# (163, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_forte_i.wav: 163 frames
# (175, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_forte_o.wav: 175 frames
# (156, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_forte_a.wav: 156 frames
# (155, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_forte_e.wav: 155 frames
# (194, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_forte_a.wav: 194 frames
# (179, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_forte_e.wav: 179 frames
# (203, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_piano_i.wav: 203 frames
# (182, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_piano_e.wav: 182 frames
# (177, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_piano_a.wav: 177 frames
# (196, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_piano_o.wav: 196 frames
# (159, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_piano_i.wav: 159 frames
# (157, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_piano_a.wav: 157 frames
# (201, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_fast_piano_u.wav: 201 frames
# (160, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_piano_e.wav: 160 frames
# (166, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_piano_o.wav: 166 frames
# (164, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_fast_piano_u.wav: 164 frames
# (634, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_forte_u.wav: 634 frames
# (505, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_forte_a.wav: 505 frames
# (549, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_forte_e.wav: 549 frames
# (657, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_forte_i.wav: 657 frames
# (589, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_forte_o.wav: 589 frames
# (623, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_forte_o.wav: 623 frames
# (626, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_forte_i.wav: 626 frames
# (621, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_forte_e.wav: 621 frames
# (623, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_forte_u.wav: 623 frames
# (612, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_forte_a.wav: 612 frames
# (585, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_piano_e.wav: 585 frames
# (625, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_piano_a.wav: 625 frames
# (606, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_piano_e.wav: 606 frames
# (603, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_piano_i.wav: 603 frames
# (622, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_piano_a.wav: 622 frames
# (621, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_piano_o.wav: 621 frames
# (652, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_piano_i.wav: 652 frames
# (654, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_piano_u.wav: 654 frames
# (614, 1025)
# ✅ Saved trimmed features for f7_arpeggios_c_slow_piano_o.wav: 614 frames
# (626, 1025)
# ✅ Saved trimmed features for f7_arpeggios_f_slow_piano_u.wav: 626 frames
# (992, 1025)
# ✅ Saved trimmed features for f7_scales_straight_a.wav: 992 frames
# (975, 1025)
# ✅ Saved trimmed features for f7_scales_straight_o.wav: 975 frames
# (953, 1025)
# ✅ Saved trimmed features for f7_scales_straight_u.wav: 953 frames
# (963, 1025)
# ✅ Saved trimmed features for f7_scales_straight_i.wav: 963 frames
# (1011, 1025)
# ✅ Saved trimmed features for f7_scales_straight_e.wav: 1011 frames
# (1004, 1025)
# ✅ Saved trimmed features for f7_scales_vibrato_i.wav: 1004 frames
# (1017, 1025)
# ✅ Saved trimmed features for f7_scales_vibrato_a.wav: 1017 frames
# (1022, 1025)
# ✅ Saved trimmed features for f7_scales_vibrato_u.wav: 1022 frames
# (977, 1025)
# ✅ Saved trimmed features for f7_scales_vibrato_e.wav: 977 frames
# (1055, 1025)
# ✅ Saved trimmed features for f7_scales_vibrato_o.wav: 1055 frames
# (274, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_forte_e.wav: 274 frames
# (256, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_forte_a.wav: 256 frames
# (265, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_forte_o.wav: 265 frames
# (253, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_forte_i.wav: 253 frames
# (254, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_forte_u.wav: 254 frames
# (257, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_forte_o.wav: 257 frames
# (257, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_forte_a.wav: 257 frames
# (248, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_forte_i.wav: 248 frames
# (258, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_forte_u.wav: 258 frames
# (253, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_forte_e.wav: 253 frames
# (299, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_piano_i.wav: 299 frames
# (270, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_piano_e.wav: 270 frames
# (252, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_piano_e.wav: 252 frames
# (263, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_piano_u.wav: 263 frames
# (298, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_piano_u.wav: 298 frames
# (271, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_piano_a.wav: 271 frames
# (261, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_piano_a.wav: 261 frames
# (293, 1025)
# ✅ Saved trimmed features for f7_scales_f_fast_piano_o.wav: 293 frames
# (262, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_piano_o.wav: 262 frames
# (261, 1025)
# ✅ Saved trimmed features for f7_scales_c_fast_piano_i.wav: 261 frames
# (905, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_forte_o.wav: 905 frames
# (1073, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_forte_i.wav: 1073 frames
# (1005, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_forte_o.wav: 1005 frames
# (1041, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_forte_a.wav: 1041 frames
# (1081, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_forte_u.wav: 1081 frames
# (919, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_forte_u.wav: 919 frames
# (910, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_forte_e.wav: 910 frames
# (1011, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_forte_e.wav: 1011 frames
# (907, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_forte_i.wav: 907 frames
# (886, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_forte_a.wav: 886 frames
# (1055, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano_u.wav: 1055 frames
# (975, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_piano_e.wav: 975 frames
# (943, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_piano_o.wav: 943 frames
# (934, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano_e.wav: 934 frames
# (1019, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano_o.wav: 1019 frames
# (980, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano_i.wav: 980 frames
# (1013, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano_a.wav: 1013 frames
# (931, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_piano_a.wav: 931 frames
# (960, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_piano_i.wav: 960 frames
# (986, 1025)
# ✅ Saved trimmed features for f7_scales_f_slow_piano_u.wav: 986 frames
# (6111, 1025)
# ✅ Saved trimmed features for f7_scales_c_slow_piano.wav: 6111 frames
# (503, 1025)
# ✅ Saved trimmed features for f7_long_straight_o.wav: 503 frames
# (509, 1025)
# ✅ Saved trimmed features for f7_long_straight_i.wav: 509 frames
# (465, 1025)
# ✅ Saved trimmed features for f7_long_straight_u.wav: 465 frames
# (517, 1025)
# ✅ Saved trimmed features for f7_long_straight_e.wav: 517 frames
# (560, 1025)
# ✅ Saved trimmed features for f7_long_straight_a.wav: 560 frames
# (536, 1025)
# ✅ Saved trimmed features for f7_long_messa_a.wav: 536 frames
# (495, 1025)
# ✅ Saved trimmed features for f7_long_messa_o.wav: 495 frames
# (501, 1025)
# ✅ Saved trimmed features for f7_long_messa_u.wav: 501 frames
# (536, 1025)
# ✅ Saved trimmed features for f7_long_messa_i.wav: 536 frames
# (543, 1025)
# ✅ Saved trimmed features for f7_long_messa_e.wav: 543 frames
# (567, 1025)
# ✅ Saved trimmed features for f7_long_forte_o.wav: 567 frames
# (622, 1025)
# ✅ Saved trimmed features for f7_long_forte_i.wav: 622 frames
# (716, 1025)
# ✅ Saved trimmed features for f7_long_forte_a.wav: 716 frames
# (693, 1025)
# ✅ Saved trimmed features for f7_long_forte_e.wav: 693 frames
# (563, 1025)
# ✅ Saved trimmed features for f7_long_forte_u.wav: 563 frames
# (528, 1025)
# ✅ Saved trimmed features for f7_long_pp_i.wav: 528 frames
# (490, 1025)
# ✅ Saved trimmed features for f7_long_pp_o.wav: 490 frames
# (541, 1025)
# ✅ Saved trimmed features for f7_long_pp_e.wav: 541 frames
# (569, 1025)
# ✅ Saved trimmed features for f7_long_pp_a.wav: 569 frames
# (514, 1025)
# ✅ Saved trimmed features for f7_long_pp_u.wav: 514 frames
# (544, 1025)
# ✅ Saved trimmed features for f1_arpeggios_straight_a.wav: 544 frames
# (579, 1025)
# ✅ Saved trimmed features for f1_arpeggios_straight_e.wav: 579 frames
# (612, 1025)
# ✅ Saved trimmed features for f1_arpeggios_straight_u.wav: 612 frames
# (584, 1025)
# ✅ Saved trimmed features for f1_arpeggios_straight_o.wav: 584 frames
# (606, 1025)
# ✅ Saved trimmed features for f1_arpeggios_straight_i.wav: 606 frames
# (646, 1025)
# ✅ Saved trimmed features for f1_arpeggios_vibrato_i.wav: 646 frames
# (621, 1025)
# ✅ Saved trimmed features for f1_arpeggios_vibrato_u.wav: 621 frames
# (619, 1025)
# ✅ Saved trimmed features for f1_arpeggios_vibrato_o.wav: 619 frames
# (611, 1025)
# ✅ Saved trimmed features for f1_arpeggios_vibrato_a.wav: 611 frames
# (627, 1025)
# ✅ Saved trimmed features for f1_arpeggios_vibrato_e.wav: 627 frames
# (169, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_forte_e.wav: 169 frames
# (188, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_forte_u.wav: 188 frames
# (171, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_forte_i.wav: 171 frames
# (185, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_forte_a.wav: 185 frames
# (152, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_forte_u.wav: 152 frames
# (188, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_forte_o.wav: 188 frames
# (150, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_forte_e.wav: 150 frames
# (148, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_forte_o.wav: 148 frames
# (163, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_forte_a.wav: 163 frames
# (157, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_forte_i.wav: 157 frames
# (133, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_piano_e.wav: 133 frames
# (139, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_piano_i.wav: 139 frames
# (143, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_piano_o.wav: 143 frames
# (143, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_piano_e.wav: 143 frames
# (142, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_piano_a.wav: 142 frames
# (140, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_piano_u.wav: 140 frames
# (142, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_piano_o.wav: 142 frames
# (131, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_piano_i.wav: 131 frames
# (142, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_fast_piano_u.wav: 142 frames
# (131, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_fast_piano_a.wav: 131 frames
# (612, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_forte_i.wav: 612 frames
# (573, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_forte_e.wav: 573 frames
# (564, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_forte_u.wav: 564 frames
# (579, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_forte_e.wav: 579 frames
# (601, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_forte_a.wav: 601 frames
# (570, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_forte_a.wav: 570 frames
# (607, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_forte_i.wav: 607 frames
# (625, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_forte_o.wav: 625 frames
# (555, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_forte_u.wav: 555 frames
# (584, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_forte_o.wav: 584 frames
# (587, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_piano_e.wav: 587 frames
# (576, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_piano_i.wav: 576 frames
# (585, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_piano_o.wav: 585 frames
# (618, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_piano_a.wav: 618 frames
# (656, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_piano_o.wav: 656 frames
# (631, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_piano_i.wav: 631 frames
# (662, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_piano_u.wav: 662 frames
# (662, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_piano_a.wav: 662 frames
# (614, 1025)
# ✅ Saved trimmed features for f1_arpeggios_f_slow_piano_e.wav: 614 frames
# (578, 1025)
# ✅ Saved trimmed features for f1_arpeggios_c_slow_piano_u.wav: 578 frames
# (859, 1025)
# ✅ Saved trimmed features for f1_scales_straight_a.wav: 859 frames
# (897, 1025)
# ✅ Saved trimmed features for f1_scales_straight_e.wav: 897 frames
# (907, 1025)
# ✅ Saved trimmed features for f1_scales_straight_u.wav: 907 frames
# (902, 1025)
# ✅ Saved trimmed features for f1_scales_straight_o.wav: 902 frames
# (870, 1025)
# ✅ Saved trimmed features for f1_scales_straight_i.wav: 870 frames
# (969, 1025)
# ✅ Saved trimmed features for f1_scales_vibrato_i.wav: 969 frames
# (943, 1025)
# ✅ Saved trimmed features for f1_scales_vibrato_e.wav: 943 frames
# (894, 1025)
# ✅ Saved trimmed features for f1_scales_vibrato_a.wav: 894 frames
# (921, 1025)
# ✅ Saved trimmed features for f1_scales_vibrato_o.wav: 921 frames
# (950, 1025)
# ✅ Saved trimmed features for f1_scales_vibrato_u.wav: 950 frames
# (281, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_forte_u.wav: 281 frames
# (290, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_forte_i.wav: 290 frames
# (283, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_forte_u.wav: 283 frames
# (284, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_forte_a.wav: 284 frames
# (289, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_forte_o.wav: 289 frames
# (301, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_forte_e.wav: 301 frames
# (305, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_forte_e.wav: 305 frames
# (285, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_forte_i.wav: 285 frames
# (307, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_forte_o.wav: 307 frames
# (299, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_forte_a.wav: 299 frames
# (267, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_piano_e.wav: 267 frames
# (279, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_piano_u.wav: 279 frames
# (272, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_piano_e.wav: 272 frames
# (276, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_piano_o.wav: 276 frames
# (289, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_piano_i.wav: 289 frames
# (296, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_piano_a.wav: 296 frames
# (285, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_piano_u.wav: 285 frames
# (276, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_piano_a.wav: 276 frames
# (305, 1025)
# ✅ Saved trimmed features for f1_scales_f_fast_piano_o.wav: 305 frames
# (271, 1025)
# ✅ Saved trimmed features for f1_scales_c_fast_piano_i.wav: 271 frames
# (953, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_forte_e.wav: 953 frames
# (942, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_forte_u.wav: 942 frames
# (903, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_forte_a.wav: 903 frames
# (963, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_forte_i.wav: 963 frames
# (897, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_forte_e.wav: 897 frames
# (957, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_forte_i.wav: 957 frames
# (956, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_forte_o.wav: 956 frames
# (901, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_forte_a.wav: 901 frames
# (916, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_forte_u.wav: 916 frames
# (917, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_forte_o.wav: 917 frames
# (964, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_piano_i.wav: 964 frames
# (974, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_piano_e.wav: 974 frames
# (988, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_piano_a.wav: 988 frames
# (993, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_piano_i.wav: 993 frames
# (947, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_piano_a.wav: 947 frames
# (1001, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_piano_e.wav: 1001 frames
# (942, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_piano_o.wav: 942 frames
# (927, 1025)
# ✅ Saved trimmed features for f1_scales_c_slow_piano_u.wav: 927 frames
# (1000, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_piano_o.wav: 1000 frames
# (975, 1025)
# ✅ Saved trimmed features for f1_scales_f_slow_piano_u.wav: 975 frames
# (831, 1025)
# ✅ Saved trimmed features for f1_long_straight_a.wav: 831 frames
# (743, 1025)
# ✅ Saved trimmed features for f1_long_straight_o.wav: 743 frames
# (727, 1025)
# ✅ Saved trimmed features for f1_long_straight_e.wav: 727 frames
# (773, 1025)
# ✅ Saved trimmed features for f1_long_straight_u.wav: 773 frames
# (764, 1025)
# ✅ Saved trimmed features for f1_long_straight_i.wav: 764 frames
# (1115, 1025)
# ✅ Saved trimmed features for f1_long_messa_i.wav: 1115 frames
# (1056, 1025)
# ✅ Saved trimmed features for f1_long_messa_o.wav: 1056 frames
# (999, 1025)
# ✅ Saved trimmed features for f1_long_messa_a.wav: 999 frames
# (920, 1025)
# ✅ Saved trimmed features for f1_long_messa_u.wav: 920 frames
# (1147, 1025)
# ✅ Saved trimmed features for f1_long_messa_e.wav: 1147 frames
# (809, 1025)
# ✅ Saved trimmed features for f1_long_forte_e.wav: 809 frames
# (826, 1025)
# ✅ Saved trimmed features for f1_long_forte_i.wav: 826 frames
# (812, 1025)
# ✅ Saved trimmed features for f1_long_forte_o.wav: 812 frames
# (782, 1025)
# ✅ Saved trimmed features for f1_long_forte_u.wav: 782 frames
# (813, 1025)
# ✅ Saved trimmed features for f1_long_forte_a.wav: 813 frames
# (790, 1025)
# ✅ Saved trimmed features for f1_long_pp_e.wav: 790 frames
# (745, 1025)
# ✅ Saved trimmed features for f1_long_pp_a.wav: 745 frames
# (797, 1025)
# ✅ Saved trimmed features for f1_long_pp_u.wav: 797 frames
# (774, 1025)
# ✅ Saved trimmed features for f1_long_pp_i.wav: 774 frames
# (747, 1025)
# ✅ Saved trimmed features for f1_long_pp_o.wav: 747 frames
# (613, 1025)
# ✅ Saved trimmed features for f6_arpeggios_straight_o.wav: 613 frames
# (649, 1025)
# ✅ Saved trimmed features for f6_arpeggios_straight_i.wav: 649 frames
# (672, 1025)
# ✅ Saved trimmed features for f6_arpeggios_straight_a.wav: 672 frames
# (624, 1025)
# ✅ Saved trimmed features for f6_arpeggios_straight_e.wav: 624 frames
# (616, 1025)
# ✅ Saved trimmed features for f6_arpeggios_straight_u.wav: 616 frames
# (672, 1025)
# ✅ Saved trimmed features for f6_arpeggios_vibrato_e.wav: 672 frames
# (671, 1025)
# ✅ Saved trimmed features for f6_arpeggios_vibrato_i.wav: 671 frames
# (680, 1025)
# ✅ Saved trimmed features for f6_arpeggios_vibrato_u.wav: 680 frames
# (670, 1025)
# ✅ Saved trimmed features for f6_arpeggios_vibrato_a.wav: 670 frames
# (668, 1025)
# ✅ Saved trimmed features for f6_arpeggios_vibrato_o.wav: 668 frames
# (165, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_forte_o.wav: 165 frames
# (170, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_forte_u.wav: 170 frames
# (156, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_forte_e.wav: 156 frames
# (167, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_forte_e.wav: 167 frames
# (160, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_forte_i.wav: 160 frames
# (159, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_forte_i.wav: 159 frames
# (176, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_forte_u.wav: 176 frames
# (186, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_forte_o.wav: 186 frames
# (150, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_forte_a.wav: 150 frames
# (145, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_forte_a.wav: 145 frames
# (184, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_piano_o.wav: 184 frames
# (170, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_piano_e.wav: 170 frames
# (151, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_piano_a.wav: 151 frames
# (167, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_piano_a.wav: 167 frames
# (192, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_piano_u.wav: 192 frames
# (158, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_piano_u.wav: 158 frames
# (166, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_piano_o.wav: 166 frames
# (160, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_fast_piano_i.wav: 160 frames
# (162, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_piano_i.wav: 162 frames
# (156, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_fast_piano_e.wav: 156 frames
# (662, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_forte_i.wav: 662 frames
# (669, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_forte_e.wav: 669 frames
# (677, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_forte_i.wav: 677 frames
# (673, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_forte_a.wav: 673 frames
# (699, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_forte_o.wav: 699 frames
# (746, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_forte_u.wav: 746 frames
# (682, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_forte_e.wav: 682 frames
# (631, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_forte_a.wav: 631 frames
# (676, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_forte_o.wav: 676 frames
# (697, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_forte_u.wav: 697 frames
# (665, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_piano_a.wav: 665 frames
# (697, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_piano_o.wav: 697 frames
# (704, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_piano_o.wav: 704 frames
# (670, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_piano_a.wav: 670 frames
# (681, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_piano_u.wav: 681 frames
# (715, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_piano_u.wav: 715 frames
# (682, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_piano_e.wav: 682 frames
# (661, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_piano_e.wav: 661 frames
# (675, 1025)
# ✅ Saved trimmed features for f6_arpeggios_f_slow_piano_i.wav: 675 frames
# (672, 1025)
# ✅ Saved trimmed features for f6_arpeggios_c_slow_piano_i.wav: 672 frames
# (414, 1025)
# ✅ Saved trimmed features for f6_scales_straight_u.wav: 414 frames
# (395, 1025)
# ✅ Saved trimmed features for f6_scales_straight_i.wav: 395 frames
# (406, 1025)
# ✅ Saved trimmed features for f6_scales_straight_o.wav: 406 frames
# (406, 1025)
# ✅ Saved trimmed features for f6_scales_straight_a.wav: 406 frames
# (397, 1025)
# ✅ Saved trimmed features for f6_scales_straight_e.wav: 397 frames
# (505, 1025)
# ✅ Saved trimmed features for f6_scales_vibrato_u.wav: 505 frames
# (494, 1025)
# ✅ Saved trimmed features for f6_scales_vibrato_i.wav: 494 frames
# (495, 1025)
# ✅ Saved trimmed features for f6_scales_vibrato_o.wav: 495 frames
# (496, 1025)
# ✅ Saved trimmed features for f6_scales_vibrato_a.wav: 496 frames
# (503, 1025)
# ✅ Saved trimmed features for f6_scales_vibrato_e.wav: 503 frames
# (286, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_forte_a.wav: 286 frames
# (343, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_forte_o.wav: 343 frames
# (296, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_forte_o.wav: 296 frames
# (275, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_forte_a.wav: 275 frames
# (322, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_forte_i.wav: 322 frames
# (287, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_forte_i.wav: 287 frames
# (293, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_forte_u.wav: 293 frames
# (299, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_forte_u.wav: 299 frames
# (297, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_forte_e.wav: 297 frames
# (276, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_forte_e.wav: 276 frames
# (320, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_piano_o.wav: 320 frames
# (308, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_piano_e.wav: 308 frames
# (269, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_piano_a.wav: 269 frames
# (301, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_piano_i.wav: 301 frames
# (304, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_piano_u.wav: 304 frames
# (292, 1025)
# ✅ Saved trimmed features for f6_scales_c_fast_piano_a.wav: 292 frames
# (286, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_piano_u.wav: 286 frames
# (290, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_piano_i.wav: 290 frames
# (296, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_piano_o.wav: 296 frames
# (285, 1025)
# ✅ Saved trimmed features for f6_scales_f_fast_piano_e.wav: 285 frames
# (805, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_forte_o.wav: 805 frames
# (707, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_forte_u.wav: 707 frames
# (773, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_forte_e.wav: 773 frames
# (669, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_forte_o.wav: 669 frames
# (772, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_forte_u.wav: 772 frames
# (621, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_forte_e.wav: 621 frames
# (800, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_forte_i.wav: 800 frames
# (800, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_forte_a.wav: 800 frames
# (659, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_forte_i.wav: 659 frames
# (628, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_forte_a.wav: 628 frames
# (767, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_piano_o.wav: 767 frames
# (819, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_piano_i.wav: 819 frames
# (759, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_piano_i.wav: 759 frames
# (780, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_piano_u.wav: 780 frames
# (838, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_piano_o.wav: 838 frames
# (825, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_piano_e.wav: 825 frames
# (824, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_piano_a.wav: 824 frames
# (763, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_piano_e.wav: 763 frames
# (818, 1025)
# ✅ Saved trimmed features for f6_scales_f_slow_piano_u.wav: 818 frames
# (794, 1025)
# ✅ Saved trimmed features for f6_scales_c_slow_piano_a.wav: 794 frames
# (521, 1025)
# ✅ Saved trimmed features for f6_long_straight_i.wav: 521 frames
# (545, 1025)
# ✅ Saved trimmed features for f6_long_straight_o.wav: 545 frames
# (574, 1025)
# ✅ Saved trimmed features for f6_long_straight_a.wav: 574 frames
# (551, 1025)
# ✅ Saved trimmed features for f6_long_straight_u.wav: 551 frames
# (526, 1025)
# ✅ Saved trimmed features for f6_long_straight_e.wav: 526 frames
# (746, 1025)
# ✅ Saved trimmed features for f6_long_messa_a.wav: 746 frames
# (1105, 1025)
# ✅ Saved trimmed features for f6_long_messa_o.wav: 1105 frames
# (1157, 1025)
# ✅ Saved trimmed features for f6_long_messa_e.wav: 1157 frames
# (1201, 1025)
# ✅ Saved trimmed features for f6_long_messa_i.wav: 1201 frames
# (1136, 1025)
# ✅ Saved trimmed features for f6_long_messa_u.wav: 1136 frames
# (591, 1025)
# ✅ Saved trimmed features for f6_long_forte_a.wav: 591 frames
# (541, 1025)
# ✅ Saved trimmed features for f6_long_forte_o.wav: 541 frames
# (563, 1025)
# ✅ Saved trimmed features for f6_long_forte_i.wav: 563 frames
# (550, 1025)
# ✅ Saved trimmed features for f6_long_forte_u.wav: 550 frames
# (546, 1025)
# ✅ Saved trimmed features for f6_long_forte_e.wav: 546 frames
# (531, 1025)
# ✅ Saved trimmed features for f6_long_pp_o.wav: 531 frames
# (519, 1025)
# ✅ Saved trimmed features for f6_long_pp_i.wav: 519 frames
# (542, 1025)
# ✅ Saved trimmed features for f6_long_pp_u.wav: 542 frames
# (529, 1025)
# ✅ Saved trimmed features for f6_long_pp_e.wav: 529 frames
# (546, 1025)
# ✅ Saved trimmed features for f6_long_pp_a.wav: 546 frames
# (677, 1025)
# ✅ Saved trimmed features for f8_arpeggios_straight_u.wav: 677 frames
# (649, 1025)
# ✅ Saved trimmed features for f8_arpeggios_straight_a.wav: 649 frames
# (638, 1025)
# ✅ Saved trimmed features for f8_arpeggios_straight_i.wav: 638 frames
# (627, 1025)
# ✅ Saved trimmed features for f8_arpeggios_straight_e.wav: 627 frames
# (653, 1025)
# ✅ Saved trimmed features for f8_arpeggios_straight_o.wav: 653 frames
# (692, 1025)
# ✅ Saved trimmed features for f8_arpeggios_vibrato_a.wav: 692 frames
# (683, 1025)
# ✅ Saved trimmed features for f8_arpeggios_vibrato_o.wav: 683 frames
# (712, 1025)
# ✅ Saved trimmed features for f8_arpeggios_vibrato_u.wav: 712 frames
# (698, 1025)
# ✅ Saved trimmed features for f8_arpeggios_vibrato_i.wav: 698 frames
# (701, 1025)
# ✅ Saved trimmed features for f8_arpeggios_vibrato_e.wav: 701 frames
# (165, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_forte_u.wav: 165 frames
# (146, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_forte_e.wav: 146 frames
# (141, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_forte_a.wav: 141 frames
# (145, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_forte_i.wav: 145 frames
# (149, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_forte_u.wav: 149 frames
# (151, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_forte_o.wav: 151 frames
# (150, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_forte_o.wav: 150 frames
# (151, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_forte_a.wav: 151 frames
# (151, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_forte_i.wav: 151 frames
# (142, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_forte_e.wav: 142 frames
# (153, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_piano_e.wav: 153 frames
# (148, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_piano_i.wav: 148 frames
# (141, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_piano_u.wav: 141 frames
# (148, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_piano_o.wav: 148 frames
# (155, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_piano_o.wav: 155 frames
# (150, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_piano_u.wav: 150 frames
# (142, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_fast_piano_a.wav: 142 frames
# (152, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_piano_i.wav: 152 frames
# (152, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_piano_a.wav: 152 frames
# (156, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_fast_piano_e.wav: 156 frames
# (686, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_forte_i.wav: 686 frames
# (721, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_forte_o.wav: 721 frames
# (718, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_forte_u.wav: 718 frames
# (698, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_forte_a.wav: 698 frames
# (719, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_forte_o.wav: 719 frames
# (668, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_forte_a.wav: 668 frames
# (648, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_forte_e.wav: 648 frames
# (732, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_forte_u.wav: 732 frames
# (696, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_forte_i.wav: 696 frames
# (714, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_forte_e.wav: 714 frames
# (738, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_piano_a.wav: 738 frames
# (779, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_piano_u.wav: 779 frames
# (735, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_piano_e.wav: 735 frames
# (741, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_piano_i.wav: 741 frames
# (751, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_piano_o.wav: 751 frames
# (711, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_piano_a.wav: 711 frames
# (748, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_piano_o.wav: 748 frames
# (749, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_piano_e.wav: 749 frames
# (748, 1025)
# ✅ Saved trimmed features for f8_arpeggios_c_slow_piano_u.wav: 748 frames
# (734, 1025)
# ✅ Saved trimmed features for f8_arpeggios_f_slow_piano_i.wav: 734 frames
# (722, 1025)
# ✅ Saved trimmed features for f8_scales_straight_a.wav: 722 frames
# (762, 1025)
# ✅ Saved trimmed features for f8_scales_straight_u.wav: 762 frames
# (756, 1025)
# ✅ Saved trimmed features for f8_scales_straight_o.wav: 756 frames
# (746, 1025)
# ✅ Saved trimmed features for f8_scales_straight_i.wav: 746 frames
# (722, 1025)
# ✅ Saved trimmed features for f8_scales_straight_e.wav: 722 frames
# (872, 1025)
# ✅ Saved trimmed features for f8_scales_vibrato_a.wav: 872 frames
# (842, 1025)
# ✅ Saved trimmed features for f8_scales_vibrato_e.wav: 842 frames
# (850, 1025)
# ✅ Saved trimmed features for f8_scales_vibrato_o.wav: 850 frames
# (836, 1025)
# ✅ Saved trimmed features for f8_scales_vibrato_i.wav: 836 frames
# (856, 1025)
# ✅ Saved trimmed features for f8_scales_vibrato_u.wav: 856 frames
# (327, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_forte_i.wav: 327 frames
# (335, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_forte_u.wav: 335 frames
# (336, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_forte_o.wav: 336 frames
# (329, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_forte_a.wav: 329 frames
# (333, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_forte_e.wav: 333 frames
# (348, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_forte_o.wav: 348 frames
# (330, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_forte_a.wav: 330 frames
# (327, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_forte_i.wav: 327 frames
# (323, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_forte_u.wav: 323 frames
# (330, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_forte_e.wav: 330 frames
# (323, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_piano_e.wav: 323 frames
# (333, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_piano_i.wav: 333 frames
# (346, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_piano_a.wav: 346 frames
# (328, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_piano_u.wav: 328 frames
# (336, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_piano_i.wav: 336 frames
# (326, 1025)
# ✅ Saved trimmed features for f8_scales_c_fast_piano_o.wav: 326 frames
# (355, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_piano_a.wav: 355 frames
# (342, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_piano_e.wav: 342 frames
# (319, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_piano_u.wav: 319 frames
# (332, 1025)
# ✅ Saved trimmed features for f8_scales_f_fast_piano_o.wav: 332 frames
# (1013, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_forte_u.wav: 1013 frames
# (1003, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_forte_o.wav: 1003 frames
# (986, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_forte_e.wav: 986 frames
# (1022, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_forte_a.wav: 1022 frames
# (965, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_forte_o.wav: 965 frames
# (931, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_forte_a.wav: 931 frames
# (1032, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_forte_u.wav: 1032 frames
# (1008, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_forte_i.wav: 1008 frames
# (982, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_forte_i.wav: 982 frames
# (940, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_forte_e.wav: 940 frames
# (1013, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_piano_a.wav: 1013 frames
# (1008, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_piano_o.wav: 1008 frames
# (1020, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_piano_u.wav: 1020 frames
# (1073, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_piano_o.wav: 1073 frames
# (1011, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_piano_e.wav: 1011 frames
# (997, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_piano_i.wav: 997 frames
# (990, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_piano_i.wav: 990 frames
# (1091, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_piano_u.wav: 1091 frames
# (971, 1025)
# ✅ Saved trimmed features for f8_scales_c_slow_piano_a.wav: 971 frames
# (1014, 1025)
# ✅ Saved trimmed features for f8_scales_f_slow_piano_e.wav: 1014 frames
# (1027, 1025)
# ✅ Saved trimmed features for f8_long_straight_o.wav: 1027 frames
# (1187, 1025)
# ✅ Saved trimmed features for f8_long_straight_a.wav: 1187 frames
# (1024, 1025)
# ✅ Saved trimmed features for f8_long_straight_e.wav: 1024 frames
# (1094, 1025)
# ✅ Saved trimmed features for f8_long_straight_u.wav: 1094 frames
# (1050, 1025)
# ✅ Saved trimmed features for f8_long_straight_i.wav: 1050 frames
# (1098, 1025)
# ✅ Saved trimmed features for f8_long_messa_u.wav: 1098 frames
# (1133, 1025)
# ✅ Saved trimmed features for f8_long_messa_i.wav: 1133 frames
# (1106, 1025)
# ✅ Saved trimmed features for f8_long_messa_o.wav: 1106 frames
# (1147, 1025)
# ✅ Saved trimmed features for f8_long_messa_e.wav: 1147 frames
# (1199, 1025)
# ✅ Saved trimmed features for f8_long_messa_a.wav: 1199 frames
# (1039, 1025)
# ✅ Saved trimmed features for f8_long_forte_e.wav: 1039 frames
# (1343, 1025)
# ✅ Saved trimmed features for f8_long_forte_a.wav: 1343 frames
# (1123, 1025)
# ✅ Saved trimmed features for f8_long_forte_u.wav: 1123 frames
# (1066, 1025)
# ...
# (474, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_forte_u.wav: 474 frames
# (607, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_forte_a.wav: 607 frames
# (389, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_piano_o.wav: 389 frames
# (356, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_piano_e.wav: 356 frames
# (148, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_piano_i.wav: 148 frames
# (329, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_piano_a.wav: 329 frames
# (448, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_piano_u.wav: 448 frames
# (343, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_piano_i.wav: 343 frames
# (234, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_piano_o.wav: 234 frames
# (330, 1025)
# ✅ Saved trimmed features for m8_arpeggios_c_slow_piano_u.wav: 330 frames
# (461, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_piano_a.wav: 461 frames
# (478, 1025)
# ✅ Saved trimmed features for m8_arpeggios_f_slow_piano_e.wav: 478 frames
# (662, 1025)
# ✅ Saved trimmed features for m8_scales_straight_i.wav: 662 frames
# (664, 1025)
# ✅ Saved trimmed features for m8_scales_straight_e.wav: 664 frames
# (669, 1025)
# ✅ Saved trimmed features for m8_scales_straight_o.wav: 669 frames
# (682, 1025)
# ✅ Saved trimmed features for m8_scales_straight_u.wav: 682 frames
# (647, 1025)
# ✅ Saved trimmed features for m8_scales_straight_a.wav: 647 frames
# (659, 1025)
# ✅ Saved trimmed features for m8_scales_vibrato_e.wav: 659 frames
# (704, 1025)
# ✅ Saved trimmed features for m8_scales_vibrato_i.wav: 704 frames
# (750, 1025)
# ✅ Saved trimmed features for m8_scales_vibrato_a.wav: 750 frames
# (749, 1025)
# ✅ Saved trimmed features for m8_scales_vibrato_o.wav: 749 frames
# (773, 1025)
# ✅ Saved trimmed features for m8_scales_vibrato_u.wav: 773 frames
# (353, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_forte_a.wav: 353 frames
# (326, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_forte_o.wav: 326 frames
# (347, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_forte_u.wav: 347 frames
# (326, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_forte_o.wav: 326 frames
# (300, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_forte_a.wav: 300 frames
# (342, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_forte_u.wav: 342 frames
# (326, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_forte_e.wav: 326 frames
# (327, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_forte_i.wav: 327 frames
# (309, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_forte_e.wav: 309 frames
# (305, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_forte_i.wav: 305 frames
# (285, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_piano_e.wav: 285 frames
# (280, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_piano_a.wav: 280 frames
# (278, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_piano_u.wav: 278 frames
# (301, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_piano_i.wav: 301 frames
# (287, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_piano_e.wav: 287 frames
# (284, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_piano_o.wav: 284 frames
# (301, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_piano_u.wav: 301 frames
# (244, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_piano_i.wav: 244 frames
# (281, 1025)
# ✅ Saved trimmed features for m8_scales_f_fast_piano_a.wav: 281 frames
# (304, 1025)
# ✅ Saved trimmed features for m8_scales_c_fast_piano_o.wav: 304 frames
# (668, 1025)
# ✅ Saved trimmed features for m8_scales_f_sow_forte_e.wav: 668 frames
# (667, 1025)
# ✅ Saved trimmed features for m8_scales_f_sow_forte_a.wav: 667 frames
# (646, 1025)
# ✅ Saved trimmed features for m8_scales_f_sow_forte_u.wav: 646 frames
# (634, 1025)
# ✅ Saved trimmed features for m8_scales_f_sow_forte_i.wav: 634 frames
# (666, 1025)
# ✅ Saved trimmed features for m8_scales_c_sow_forte_u.wav: 666 frames
# (637, 1025)
# ✅ Saved trimmed features for m8_scales_c_sow_forte_a.wav: 637 frames
# (644, 1025)
# ✅ Saved trimmed features for m8_scales_c_sow_forte_o.wav: 644 frames
# (660, 1025)
# ✅ Saved trimmed features for m8_scales_f_sow_forte_o.wav: 660 frames
# (658, 1025)
# ✅ Saved trimmed features for m8_scales_c_sow_forte_i.wav: 658 frames
# (644, 1025)
# ✅ Saved trimmed features for m8_scales_c_sow_forte_e.wav: 644 frames
# (426, 1025)
# ✅ Saved trimmed features for m8_scales_f_slow_piano_i.wav: 426 frames
# (626, 1025)
# ✅ Saved trimmed features for m8_scales_f_slow_piano_e.wav: 626 frames
# (660, 1025)
# ✅ Saved trimmed features for m8_scales_c_slow_piano_e.wav: 660 frames
# (655, 1025)
# ✅ Saved trimmed features for m8_scales_c_slow_piano_a.wav: 655 frames
# (649, 1025)
# ✅ Saved trimmed features for m8_scales_c_slow_piano_u.wav: 649 frames
# (689, 1025)
# ✅ Saved trimmed features for m8_scales_f_slow_piano_a.wav: 689 frames
# (649, 1025)
# ✅ Saved trimmed features for m8_scales_c_slow_piano_o.wav: 649 frames
# (490, 1025)
# ✅ Saved trimmed features for m8_scales_f_slow_piano_u.wav: 490 frames
# (616, 1025)
# ✅ Saved trimmed features for m8_scales_c_slow_piano_i.wav: 616 frames
# (574, 1025)
# ✅ Saved trimmed features for m8_scales_f_slow_piano_o.wav: 574 frames
# (811, 1025)
# ✅ Saved trimmed features for m8_long_straight_a.wav: 811 frames
# (746, 1025)
# ✅ Saved trimmed features for m8_long_straight_o.wav: 746 frames
# (740, 1025)
# ✅ Saved trimmed features for m8_long_straight_i.wav: 740 frames
# (733, 1025)
# ✅ Saved trimmed features for m8_long_straight_u.wav: 733 frames
# (797, 1025)
# ✅ Saved trimmed features for m8_long_straight_e.wav: 797 frames
# (871, 1025)
# ✅ Saved trimmed features for m8_long_messa_a.wav: 871 frames
# (825, 1025)
# ✅ Saved trimmed features for m8_long_messa_i.wav: 825 frames
# (811, 1025)
# ✅ Saved trimmed features for m8_long_messa_e.wav: 811 frames
# (786, 1025)
# ✅ Saved trimmed features for m8_long_messa_o.wav: 786 frames
# (788, 1025)
# ✅ Saved trimmed features for m8_long_messa_u.wav: 788 frames
# (663, 1025)
# ✅ Saved trimmed features for m8_long_forte_u.wav: 663 frames
# (743, 1025)
# ✅ Saved trimmed features for m8_long_forte_i.wav: 743 frames
# (761, 1025)
# ✅ Saved trimmed features for m8_long_forte_a.wav: 761 frames
# (747, 1025)
# ✅ Saved trimmed features for m8_long_forte_e.wav: 747 frames
# (707, 1025)
# ✅ Saved trimmed features for m8_long_forte_o.wav: 707 frames
# (693, 1025)
# ✅ Saved trimmed features for m8_long_pp_e.wav: 693 frames
# (677, 1025)
# ✅ Saved trimmed features for m8_long_pp_o.wav: 677 frames
# (665, 1025)
# ✅ Saved trimmed features for m8_long_pp_i.wav: 665 frames
# (670, 1025)
# ✅ Saved trimmed features for m8_long_pp_a.wav: 670 frames
# (706, 1025)
# ✅ Saved trimmed features for m8_long_pp_u.wav: 706 frames
# (595, 1025)
# ✅ Saved trimmed features for m6_arpeggios_straight_u.wav: 595 frames
# (548, 1025)
# ✅ Saved trimmed features for m6_arpeggios_straight_a.wav: 548 frames
# (615, 1025)
# ✅ Saved trimmed features for m6_arpeggios_straight_e.wav: 615 frames
# (767, 1025)
# ✅ Saved trimmed features for m6_arpeggios_straight_i.wav: 767 frames
# (617, 1025)
# ✅ Saved trimmed features for m6_arpeggios_straight_o.wav: 617 frames
# (844, 1025)
# ✅ Saved trimmed features for m6_arpeggios_vibrato_e.wav: 844 frames
# (759, 1025)
# ✅ Saved trimmed features for m6_arpeggios_vibrato_a.wav: 759 frames
# (866, 1025)
# ✅ Saved trimmed features for m6_arpeggios_vibrato_i.wav: 866 frames
# (925, 1025)
# ✅ Saved trimmed features for m6_arpeggios_vibrato_o.wav: 925 frames
# (918, 1025)
# ✅ Saved trimmed features for m6_arpeggios_vibrato_u.wav: 918 frames
# (185, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_forte_e.wav: 185 frames
# (188, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_forte_i.wav: 188 frames
# (186, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_forte_o.wav: 186 frames
# (193, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_forte_i.wav: 193 frames
# (200, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_forte_o.wav: 200 frames
# (202, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_forte_u.wav: 202 frames
# (194, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_forte_u.wav: 194 frames
# (180, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_forte_e.wav: 180 frames
# (170, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_piano_e.wav: 170 frames
# (177, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_piano_o.wav: 177 frames
# (180, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_piano_i.wav: 180 frames
# (190, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_piano_u.wav: 190 frames
# (181, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_piano_u.wav: 181 frames
# (166, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_piano_o.wav: 166 frames
# (164, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_fast_piano_i.wav: 164 frames
# (175, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_fast_piano_e.wav: 175 frames
# (406, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_forte_i.wav: 406 frames
# (344, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_forte_a.wav: 344 frames
# (350, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_forte_e.wav: 350 frames
# (434, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_forte_u.wav: 434 frames
# (392, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_forte_e.wav: 392 frames
# (364, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_forte_a.wav: 364 frames
# (442, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_forte_o.wav: 442 frames
# (443, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_forte_o.wav: 443 frames
# (422, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_forte_i.wav: 422 frames
# (448, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_forte_u.wav: 448 frames
# (435, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_piano_a.wav: 435 frames
# (568, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_piano_i.wav: 568 frames
# (556, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_piano_u.wav: 556 frames
# (555, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_piano_o.wav: 555 frames
# (605, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_piano_e.wav: 605 frames
# (491, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_piano_e.wav: 491 frames
# (478, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_piano_a.wav: 478 frames
# (572, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_piano_o.wav: 572 frames
# (573, 1025)
# ✅ Saved trimmed features for m6_arpeggios_c_slow_piano_i.wav: 573 frames
# (612, 1025)
# ✅ Saved trimmed features for m6_arpeggios_f_slow_piano_u.wav: 612 frames
# (660, 1025)
# ✅ Saved trimmed features for m6_scales_straight_u.wav: 660 frames
# (644, 1025)
# ✅ Saved trimmed features for m6_scales_straight_a.wav: 644 frames
# (685, 1025)
# ✅ Saved trimmed features for m6_scales_straight_i.wav: 685 frames
# (643, 1025)
# ✅ Saved trimmed features for m6_scales_straight_e.wav: 643 frames
# (691, 1025)
# ✅ Saved trimmed features for m6_scales_straight_o.wav: 691 frames
# (1348, 1025)
# ✅ Saved trimmed features for m6_scales_vibrato_e.wav: 1348 frames
# (1435, 1025)
# ✅ Saved trimmed features for m6_scales_vibrato_i.wav: 1435 frames
# (1466, 1025)
# ✅ Saved trimmed features for m6_scales_vibrato_o.wav: 1466 frames
# (1493, 1025)
# ✅ Saved trimmed features for m6_scales_vibrato_u.wav: 1493 frames
# (1181, 1025)
# ✅ Saved trimmed features for m6_scales_vibrato_a.wav: 1181 frames
# (307, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_forte_e.wav: 307 frames
# (273, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_forte_a.wav: 273 frames
# (289, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_forte_u.wav: 289 frames
# (263, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_forte_o.wav: 263 frames
# (280, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_forte_e.wav: 280 frames
# (302, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_forte_u.wav: 302 frames
# (302, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_forte_o.wav: 302 frames
# (289, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_forte_a.wav: 289 frames
# (300, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_forte_i.wav: 300 frames
# (307, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_forte_i.wav: 307 frames
# (238, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_piano_u.wav: 238 frames
# (297, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_piano_a.wav: 297 frames
# (328, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_piano_e.wav: 328 frames
# (296, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_piano_e.wav: 296 frames
# (291, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_piano_o.wav: 291 frames
# (303, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_piano_o.wav: 303 frames
# (273, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_piano_i.wav: 273 frames
# (300, 1025)
# ✅ Saved trimmed features for m6_scales_c_fast_piano_a.wav: 300 frames
# (319, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_piano_i.wav: 319 frames
# (255, 1025)
# ✅ Saved trimmed features for m6_scales_f_fast_piano_u.wav: 255 frames
# (1442, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_forte_o.wav: 1442 frames
# (1445, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_forte_u.wav: 1445 frames
# (1437, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_forte_e.wav: 1437 frames
# (1524, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_forte_i.wav: 1524 frames
# (1312, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_forte_u.wav: 1312 frames
# (1380, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_forte_e.wav: 1380 frames
# (1380, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_forte_o.wav: 1380 frames
# (1477, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_forte_a.wav: 1477 frames
# (1352, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_forte_a.wav: 1352 frames
# (1370, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_forte_i.wav: 1370 frames
# (1400, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_piano_u.wav: 1400 frames
# (1464, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_piano_i.wav: 1464 frames
# (1322, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_piano_a.wav: 1322 frames
# (1414, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_piano_e.wav: 1414 frames
# (1392, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_piano_o.wav: 1392 frames
# (1433, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_piano_u.wav: 1433 frames
# (1298, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_piano_a.wav: 1298 frames
# (1379, 1025)
# ✅ Saved trimmed features for m6_scales_f_slow_piano_e.wav: 1379 frames
# (1524, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_piano_i.wav: 1524 frames
# (1412, 1025)
# ✅ Saved trimmed features for m6_scales_c_slow_piano_o.wav: 1412 frames
# (991, 1025)
# ✅ Saved trimmed features for m6_long_straight_u.wav: 991 frames
# (1067, 1025)
# ✅ Saved trimmed features for m6_long_straight_i.wav: 1067 frames
# (1068, 1025)
# ✅ Saved trimmed features for m6_long_straight_e.wav: 1068 frames
# (1109, 1025)
# ✅ Saved trimmed features for m6_long_straight_a.wav: 1109 frames
# (983, 1025)
# ✅ Saved trimmed features for m6_long_straight_o.wav: 983 frames
# (966, 1025)
# ✅ Saved trimmed features for m6_long_messa_i.wav: 966 frames
# (1095, 1025)
# ✅ Saved trimmed features for m6_long_messa_o.wav: 1095 frames
# (1168, 1025)
# ✅ Saved trimmed features for m6_long_messa_u.wav: 1168 frames
# (931, 1025)
# ✅ Saved trimmed features for m6_long_messa_a.wav: 931 frames
# (938, 1025)
# ✅ Saved trimmed features for m6_long_messa_e.wav: 938 frames
# (953, 1025)
# ✅ Saved trimmed features for m6_long_forte_i.wav: 953 frames
# (1088, 1025)
# ✅ Saved trimmed features for m6_long_forte_u.wav: 1088 frames
# (872, 1025)
# ✅ Saved trimmed features for m6_long_forte_a.wav: 872 frames
# (802, 1025)
# ✅ Saved trimmed features for m6_long_forte_o.wav: 802 frames
# (941, 1025)
# ✅ Saved trimmed features for m6_long_forte_e.wav: 941 frames
# (1083, 1025)
# ✅ Saved trimmed features for m6_long_pp_a.wav: 1083 frames
# (769, 1025)
# ✅ Saved trimmed features for m6_long_pp_u.wav: 769 frames
# (1129, 1025)
# ✅ Saved trimmed features for m6_long_pp_e.wav: 1129 frames
# (915, 1025)
# ✅ Saved trimmed features for m6_long_pp_o.wav: 915 frames
# (834, 1025)
# ✅ Saved trimmed features for m6_long_pp_i.wav: 834 frames
